# %%
# matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# 1000 równo rozmieszczonych punktów w przedziale $(-\pi, \pi)$

# %%
x = np.linspace(-np.pi, np.pi, 1000)

# %% [markdown]
# dla każdego z tych punktów $x_i$ liczę $\sin(x_i)$

# %%
y = np.

# %% [markdown]
# na wykres nanosimy pary punktów $(x_i, y_i) = (x_i, \sin(x_i))$, łączymy linią.

# %%
plt.plot(x, y)
None

# %%
x2 = np.linspace(-np.pi, np.pi, 1000)
y2 = np.sin(x2)
plt.plot(x2, y2)

x = np.linspace(-np.pi, np.pi, 6)
y = np.sin(x)
plt.plot(x, y, '--r')

None

# %%
import math

@np.vectorize
def sinus_kwadrat(x):
    return math.sin(x)**2

# %%
x2 = np.linspace(-np.pi, np.pi, 1000)
y2 = sinus_kwadrat(x2+np.pi/4)*2-1
plt.plot(x2, y2)

x = np.linspace(-np.pi, np.pi, 1000)
y = np.sin(2*x)
plt.plot(x, y, '--r')

None

# %% [markdown]
# $$ \operatorname{sinc}(x) = \begin{cases}\frac{\sin(x)}{x}, & \text{ gdy } x \neq 0,\\ 1, & \text{ gdy } x = 0. \end{cases}$$

# %%
import math

@np.vectorize
def sinc(x):
    return 1 if x==0 else math.sin(x)/x

# %%
x = np.linspace(-5*np.pi, 5*np.pi, 1000)

y = sinc(x)
plt.plot(x2, y2, label=r"$\sinc(x)$")

y = np.sin(x)
plt.plot(x, y, '--r', linewidth=0.5, label=r"$\sin(x)$")

x = np.linspace(0.001, 5*np.pi, 1000)

y = 1/x
plt.plot(x, y, '--g', linewidth=0.5, label=r"$\frac{1}{x}$")

y = -1/x
plt.plot(x, y, '--g', linewidth=0.5)

x = np.linspace(-5*np.pi, -0.001, 1000)

y = 1/x
plt.plot(x, y, '--g', linewidth=0.5)

y = -1/x
plt.plot(x, y, '--g', linewidth=0.5)

plt.ylim(-3, 3)
plt.title(r"Funkcja $\sinc(x)$")
plt.xlabel("$x$")
plt.ylabel("$y$")

podpisy = []
for i in range(-5, 6, 1):
    if i == 0:
        podpisy.append("$0$")
    else:
        podpisy.append(fr"${i}\pi$")

plt.xticks(np.arange(-5*np.pi, 6*np.pi, np.pi), podpisy)

plt.legend()

plt.savefig("rysunek.png")
None

# %%
# Przykład z dokumentacji, https://matplotlib.org/gallery/index.html

import numpy as np
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(6, 3), subplot_kw=dict(aspect="equal"))

recipe = ["375 g flour",
          "75 g sugar",
          "250 g butter",
          "300 g berries"]

data = [float(x.split()[0]) for x in recipe]
ingredients = [x.split()[-1] for x in recipe]


def func(pct, allvals):
    absolute = int(pct/100.*np.sum(allvals))
    return "{:.1f}%\n({:d} g)".format(pct, absolute)


wedges, texts, autotexts = ax.pie(data, autopct=lambda pct: func(pct, data),
                                  textprops=dict(color="w"))

ax.legend(wedges, ingredients,
          title="Ingredients",
          loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

plt.setp(autotexts, size=8, weight="bold")

ax.set_title("Matplotlib bakery: A pie")

plt.show()
